# %% [markdown]
# ## Notebook is created for IBM Capstone Project. It has few libraries import and few simple print statements

# %%
# Importing libs
import pandas as pd
import numpy as np
import datetime

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
x=10
y=5
z = x/y
print(z)
# Out:
# 2.0
